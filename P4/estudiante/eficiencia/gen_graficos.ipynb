# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
import pandas as pd 
sb.set()

# %%
lon_efi=pd.read_csv('datos_ejecuciones/datos_l_0.csv', index_col=0)
punt_efi=pd.read_csv('datos_ejecuciones/datos_p_0.csv', index_col=0)
lon_in=pd.read_csv('datos_ejecuciones/datos_l_1.csv', index_col=0)
punt_in=pd.read_csv('datos_ejecuciones/datos_p_1.csv', index_col=0)

# %%
lon_in.plot()
# Out:
# <AxesSubplot: xlabel='Tamano'>

# %%
    lon_efi['4'].plot()
    
    # lon_efi['4'].plot()
# Out:
# <AxesSubplot: xlabel='Tamano'>
